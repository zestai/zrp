# %% [markdown]
# # How to Build a Geo Lookup Table
# The purpose of this notebook is to illustrate how to build a Geo-Lookup table, to use for geocoding addresses. In this example Alabama county level Census Tigerline shapefiles will be used generate a lookup table.

# %%
from os.path import join, expanduser
import datetime as dt
import pandas as pd
import numpy as np
import warnings
import glob
import json
import sys
import os
import re

# %%
warnings.filterwarnings(action='once')
home = expanduser('~')

# %%
src_path = '{}/zest-race-predictor/playground/kam/zrp'.format(home)
sys.path.append(src_path)

# %% [markdown]
# Predefine paths & required parameters

# %%
support_files_path = "/d/shared/zrp/shared_data"
year = "2020"
st_cty_code = "01001"

# %% [markdown]
# Import Geo Lookup Functions

# %%
from prepare.geo_lookup import *

# %% [markdown]
# ### Initialize `GeoLookUpBuilder`
# This class constructs geographic lookup tables that enable geocoding.

# %%
geo_build = GeoLookUpBuilder(support_files_path = support_files_path, year = year)

# %% [markdown]
# ### Run `GeoLookUpBuilder`
# Provide the state-county fips code to build a county level lookup table.

# %%
# %%time
output = geo_build.transform(st_cty_code, False)
# Out:
# Shapefile input: /d/shared/zrp/shared_data/raw/geo/2020
# Lookup Table output: /d/shared/zrp/shared_data/processed/geo/2020
#
#  ... Loading requirements
# /home/kam/zest-race-predictor/playground/kam/zrp/prepare/utils.py:96: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   dictList.append(next(src)["properties"])
#  ... Creating lookup table
#  ... Formatting lookup table
#    [Start] Processing lookup data
#      ...processing
#    [Completed] Processing lookup data
# No tables were saved
# CPU times: user 6.86 s, sys: 171 ms, total: 7.03 s
# Wall time: 7.22 s

# %% [markdown]
# ### Preview

# %%
output.head()
# Out:
#         TLID       TFID           ARIDL           ARIDR       LINEARID  \
# 0  645547480  265281980   4004702275423  40010888101733  1102971723827
# 1  618373091  265281980   4002641174315   4002641174318   110585080643
# 2  618373124  265281980  40010888100743   4003990900908  1102641174929
# 3  618373241  265281980   4005554316924   4005554316988   110585093561
# 4    2827302  265281980   4005599635001   4005552602396   110585091272
#
#     ZEST_FULLNAME FROMHN TOHN ZEST_ZIP EDGE_MTFCC  ... PUMACE RAW_ZEST_ZIP  \
# 0  WINCHESTER WAY    209  211    36067      S1400  ...   NONE        36067
# 1       US HWY 82    298  170    36067      S1200  ...   NONE        36067
# 2  HEARTHSTONE DR    808  800    36067      S1400  ...   NONE        36067
# 3   MANTLEWOOD CT    112  100    36067      S1400  ...   NONE        36067
# 4       THOMAS LN    101  115    36067      S1400  ...   NONE        36067
#
#   RAW_ZEST_STATEFP RAW_ZEST_COUNTYFP RAW_ZEST_FULLNAME RAW_ZEST_TRACTCE  \
# 0               01               001    WINCHESTER WAY           020600
# 1               01               001         US HWY 82           020600
# 2               01               001    HEARTHSTONE DR           020600
# 3               01               001     MANTLEWOOD CT           020600
# 4               01               001         THOMAS LN           020600
#
#   RAW_ZEST_BLKGRPCE GEOID_ZIP     GEOID_CT      GEOID_BG
# 0                 3     36067  01001020600  010010206003
# 1                 3     36067  01001020600  010010206003
# 2                 3     36067  01001020600  010010206003
# 3                 3     36067  01001020600  010010206003
# 4                 3     36067  01001020600  010010206003
#
# [5 rows x 50 columns]

# %%
output.tail()
# Out:
#            TLID       TFID          ARIDL           ARIDR       LINEARID  \
# 2997  641780949  267800464           NONE   4005329899958  1105320854926
# 2998  641779051  215950931  4005329899485   4005329899410  1102603648065
# 3002  641842113  215954130  4005329906653   4005556332827  1105321152904
# 3003  641842126  263692778           NONE   4005554301498  1105321152990
# 3004  641842126  263692778           NONE  40020508687594  1105321152990
#
#       ZEST_FULLNAME FROMHN  TOHN ZEST_ZIP EDGE_MTFCC  ... PUMACE RAW_ZEST_ZIP  \
# 2997    DECEMBER DR   1198  1100    36051      S1400  ...   NONE        36051
# 2998      TANNER DR   2500  2598    36067      S1400  ...   NONE        36067
# 3002  AMBER ROSE DR   1998  1900    36067      S1400  ...   NONE        36067
# 3003       LUCAS CT   1500  1598    36067      S1400  ...   NONE        36067
# 3004       LUCAS CT    400   498    36067      S1400  ...   NONE        36067
#
#      RAW_ZEST_STATEFP RAW_ZEST_COUNTYFP RAW_ZEST_FULLNAME RAW_ZEST_TRACTCE  \
# 2997               01               001       DECEMBER DR           020902
# 2998               01               001         TANNER DR           021000
# 3002               01               001     AMBER ROSE DR           020803
# 3003               01               001          LUCAS CT           020803
# 3004               01               001          LUCAS CT           020803
#
#      RAW_ZEST_BLKGRPCE GEOID_ZIP     GEOID_CT      GEOID_BG
# 2997                 1     36051  01001020902  010010209021
# 2998                 2     36067  01001021000  010010210002
# 3002                 3     36067  01001020803  010010208033
# 3003                 3     36067  01001020803  010010208033
# 3004                 3     36067  01001020803  010010208033
#
# [5 rows x 50 columns]
